# %% [markdown]
# ### **Introduction to Statistics**

# %%
import pandas as pd
import numpy as np
import seaborn as sns

food_consumption = pd.read_csv("food_consumption.csv")
# Filter for Belgium
belg_consumption = food_consumption[food_consumption["country"] == "Belgium"]
# Filter for USA
usa_consumption = food_consumption[food_consumption["country"] == "USA"]

# Calculate mean and median consumption in Belgium
print(np.mean(belg_consumption["consumption"]))
print(np.median(belg_consumption["consumption"]))
# Calculate mean and median consumption in USA
print(np.mean(usa_consumption["consumption"]))
print(np.median(usa_consumption["consumption"]))
# Out:
# 42.13272727272727
# 12.59
# 44.650000000000006
# 14.58

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

food_consumption = pd.read_csv("food_consumption.csv")
# Subset for food_category equals rice
rice_consumption = food_consumption[food_consumption["food_category"] == "rice"]
# Histogram of co2_emission for rice and show plot
sns.histplot(data=rice_consumption["co2_emission"], bins=10, color="skyblue")
plt.show()

# %%
# variance and standard deviation
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# import dataset
food_consumption = pd.read_csv("food_consumption.csv")
# Print variance and sd of co2_emission for each food_category
print(food_consumption.groupby("food_category")["co2_emission"].agg([np.var, np.std]))
# Out:
#                         var         std
# food_category
# beef           88748.408132  297.906710
# dairy          17671.891985  132.935669
# eggs              21.371819    4.622966
# fish             921.637349   30.358481
# lamb_goat      16475.518363  128.356996
# nuts              35.639652    5.969895
# pork            3094.963537   55.632396
# poultry          245.026801   15.653332
# rice            2281.376243   47.763754
# soybeans           0.879882    0.938020
# wheat             71.023937    8.427570
# <ipython-input-2-7fca617ed20b>:8: FutureWarning: The provided callable <function var at 0x7a474bf1bf40> is currently using SeriesGroupBy.var. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "var" instead.
#   print(food_consumption.groupby("food_category")["co2_emission"].agg([np.var, np.std]))
# ...

# %%
# import packages
import pandas as pd
import numpy as np
import seaborn as sns

# import dataset
food_consumption = pd.read_csv("food_consumption.csv")
# Create histogram of co2_emission for food_category 'beef'
plt.hist(food_consumption[food_consumption["food_category"] == "beef"]["co2_emission"])
# Show plot
plt.show()
# Create histogram of co2_emission for food_category 'eggs'
plt.hist(food_consumption[food_consumption["food_category"] == "eggs"]["co2_emission"])
# Show plot
plt.show()

# %%
# import packages
import pandas as pd
import numpy as np
import seaborn as sns

# import dataset
food_consumption = pd.read_csv("food_consumption.csv")
# Calculate the quartiles of co2_emission
print(np.quantile(food_consumption["co2_emission"], [0, 0.25, 0.5, 0.75, 1]))
# Calculate the quintiles of co2_emission
print(np.quantile(food_consumption['co2_emission'], [0, 0.2, 0.4, 0.6, 0.8, 1]))
# Out:
# [   0.        5.21     16.53     62.5975 1712.    ]
# [   0.       3.54    11.026   25.59    99.978 1712.   ]

# %%
# find an outlier
# import packages
import pandas as pd
import numpy as np
import seaborn as sns

# import dataset
food_consumption = pd.read_csv("food_consumption.csv")
# Calculate total co2_emission per country: emissions_by_country
emissions_by_country = food_consumption.groupby('country')['co2_emission'].sum()
# print(emissions_by_country)

# Compute the first and third quartiles and IQR of emissions_by_country
q1 = np.quantile(emissions_by_country, 0.25)
q3 = np.quantile(emissions_by_country, 0.75)
iqr = q3-q1

# Calculate the lower and upper cutoffs for outliers
lower = np.quantile(emissions_by_country, 0.25) - 1.5 * iqr
upper = np.quantile(emissions_by_country, 0.75) + 1.5 * iqr

# Subset emissions_by_country to find outliers
outliers = outliers = emissions_by_country[(emissions_by_country < lower) | (emissions_by_country > upper)]
print(outliers)
# Out:
# country
# Argentina    2172.4
# Name: co2_emission, dtype: float64

# %%
# calculating probabilities
# import packages
import pandas as pd
import numpy as np
import seaborn as sns

# import dataset
food_consumption = pd.read_csv("food_consumption.csv")
# Count the deals for each product
counts = food_consumption["food_category"].value_counts()
print(counts)
# Calculate probability of picking a deal with each product
probs = counts/sum(counts)
print(probs)
# Out:
# food_category
# pork         130
# poultry      130
# beef         130
# lamb_goat    130
# fish         130
# eggs         130
# dairy        130
# wheat        130
# rice         130
# soybeans     130
# nuts         130
# Name: count, dtype: int64
# food_category
# pork         0.090909
# poultry      0.090909
# beef         0.090909
# lamb_goat    0.090909
# fish         0.090909
# eggs         0.090909
# dairy        0.090909
# wheat        0.090909
# rice         0.090909
# soybeans     0.090909
# nuts         0.090909
# Name: count, dtype: float64

# %%
# import packages
import pandas as pd
import numpy as np
import seaborn as sns

# import dataset
food_consumption = pd.read_csv("food_consumption.csv")

# %%
# import packages
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Set random seed to 334
np.random.seed(334)

# Import uniform
from scipy.stats import uniform

# Generate 1000 wait times between 0 and 30 mins
wait_times = uniform.rvs(1, 0.5, size=700)

# Create a histogram of simulated times and show plot
plt.hist(wait_times)
plt.show()

# %%
# import packages
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Import binom from scipy.stats
from scipy.stats import binom

# Set random seed to 10
np.random.seed(10)

# Simulate a single deal
#print(binom.rvs(1, 0.3, size=1))

# Simulate 52 weeks of 3 deals
deals = binom.rvs(3, 0.3, size=52)

# Print mean deals won per week
print(np.mean(deals))
# Out:
# 0.8269230769230769

# %%
#normal distributions
import pandas as pd
import matplotlib.pyplot as plt

amir_deals = pd.read_csv("amir_deals (1).csv")
# Assuming 'amir_deals' is your DataFrame
# Make sure to select the 'amount' column
amir_deals['amount'].hist(bins=10)
plt.show()

# %%
#Probabilities from the normal distribution
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm

amir_deals = pd.read_csv("amir_deals (1).csv")

# Probability of deal < 7500
prob_less_7500 = norm.cdf(7500, 5000, 2000)
print(prob_less_7500)

# Probability of deal > 1000
prob_over_1000 = 1 - norm.cdf(1000, 5000, 2000)
print(prob_over_1000)

# Probability of deal between 3000 and 7000
prob_3000_to_7000 = norm.cdf(7000, 5000, 2000) - norm.cdf(3000, 5000, 2000)
print(prob_3000_to_7000)

# Calculate amount that 25% of deals will be less than
pct_25 = norm.ppf(0.25, 5000 ,2000)
print(pct_25)
# Out:
# 0.8943502263331446
# 0.9772498680518208
# 0.6826894921370859
# 3651.0204996078364

# %%
#Simulating sales under new market conditions
#normal distribution
import matplotlib.pyplot as plt
from scipy.stats import norm

# Calculate new average amount
new_mean = 5000 * 1.2

# Calculate new standard deviation
new_sd = 2000 * 1.3

# Simulate 36 new sales
from scipy.stats import norm
new_sales = norm.rvs(new_mean, new_sd, size=36)

# Create histogram and show
import matplotlib.pyplot as plt
plt.hist(new_sales, bins=10)
plt.xlabel('Sale Amount')
plt.ylabel('Frequency')
plt.title('Distribution of New Sales')
plt.show()

# %%
#central limit theorem
#the CLT in action
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm

amir_deals = pd.read_csv("amir_deals (1).csv")

# Create a histogram of num_users and show
amir_deals["num_users"].hist()
plt.show()

# %%
#central limit theorem
#the CLT in action
import pandas as pd
import numpy as np
from scipy.stats import norm

amir_deals = pd.read_csv("amir_deals (1).csv")

# Set seed to 104
np.random.seed(104)

# Sample 20 num_users with replacement from amir_deals
samp_20 = amir_deals["num_users"].sample(20, replace=True)

# Take mean of samp_20
print(np.mean(samp_20))
# Out:
# 32.0

# %%
#central limit theorem
#the CLT in action
import pandas as pd
import numpy as np
from scipy.stats import norm

# Set seed to 104
np.random.seed(104)

# Sample 20 num_users with replacement from amir_deals and take mean
samp_20 = amir_deals['num_users'].sample(20, replace=True)
np.mean(samp_20)

sample_means = []
# Loop 100 times
for i in range(100):
  # Take sample of 20 num_users
  samp_20 = amir_deals['num_users']
  # Calculate mean of samp_20
  samp_20_mean = amir_deals['num_users'].sample(20, replace=True)
  # Append samp_20_mean to sample_means
  sample_means.append(np.mean(samp_20_mean))

sample_means
# Out:
# [31.35,
#  45.05,
#  33.55,
#  38.15,
#  50.85,
#  31.85,
#  34.65,
#  36.25,
#  38.9,
#  44.05,
#  35.45,
#  37.6,
#  37.95,
#  28.85,
#  33.3,
#  31.65,
#  45.5,
#  43.2,
#  24.4,
#  41.05,
#  37.2,
#  39.3,
#  29.45,
#  33.55,
#  45.3,
#  45.1,
#  30.95,
#  36.25,
#  37.65,
#  42.55,
#  34.55,
#  41.1,
#  36.9,
#  42.45,
#  38.45,
#  45.9,
#  42.7,
#  38.4,
#  32.55,
#  30.25,
#  38.0,
#  38.75,
#  49.3,
#  39.55,
#  49.05,
#  42.05,
#  41.0,
#  40.6,
#  58.25,
#  34.55,
#  51.2,
#  34.15,
#  36.95,
#  42.45,
#  41.85,
#  33.2,
#  36.15,
#  37.55,
#  34.2,
#  29.75,
#  42.35,
#  43.75,
#  29.0,
#  32.05,
#  31.65,
#  44.6,
#  30.85,
#  29.6,
#  37.7,
#  33.1,
#  36.35,
#  40.65,
#  45.7,
#  33.8,
#  40.1,
#  39.9,
#  33.5,
#  32.65,
#  32.85,
#  42.85,
#  35.4,
#  31.7,
#  32.0,
#  33.85,
#  36.6,
#  44.35,
#  39.9,
#  37.0,
#  37.3,
#  42.5,
#  38.35,
#  42.8,
#  44.55,
#  30.3,
#  50.45,
#  42.35,
#  40.65,
#  29.85,
#  39.3,
#  33.1]

# %%
#central limit theorem
#the CLT in action
import pandas as pd
import numpy as np
from scipy.stats import norm

amir_deals = pd.read_csv("amir_deals (1).csv")

  # Set seed to 104
np.random.seed(104)

sample_means = []
# Loop 100 times
for i in range(100):
  # Take sample of 20 num_users
  samp_20 = amir_deals['num_users'].sample(20, replace=True)
  # Calculate mean of samp_20
  samp_20_mean = np.mean(samp_20)
  # Append samp_20_mean to sample_means
  sample_means.append(samp_20_mean)

# Convert to Series and plot histogram
sample_means_series = pd.Series(sample_means)
sample_means_series.hist()
# Show plot
plt.show()

# %%
#the poisson distribution
#Tracking lead responses

#find the probability of amir responds 5 deals in a day, for 4 deals on average each day
import pandas as pd
from scipy.stats import poisson

amir_deals = pd.read_csv("amir_deals (1).csv")
# Probability of 5 responses
prob_5 = poisson.pmf(5, 4)

print(prob_5)
# Out:
# 0.1562934518505317

# %%
#the poission distribution
#tracking lead responses

#find the probability of 5 responds in a day, if amir's coworker responds ina average of 5.5
import pandas as pd
from scipy.stats import poisson

amir_deals = pd.read_csv("amir_deals (1).csv")
# Probability of 5 responses
prob_coworker = poisson.pmf(5, 5.5)

print(prob_coworker)
# Out:
# 0.17140068409793663

# %%
#the poisson distribution
#tracking lead responses

#find the probability of amir's responds to 2 responds or fewer in a day,
#if on the average Amir responds to 4 leads each day
import pandas as pd
from scipy.stats import poisson

amir_deals = pd.read_csv("amir_deals (1).csv")
# Probability of 2 or fewer responses
prob_2_or_less = poisson.cdf(2, 4)

print(prob_2_or_less)
# Out:
# 0.23810330555354436

# %%
#the poisson distribution
#tracking lead responses

#find the probability of amir's responds to more than 10 leads in a day,
#if the average of amir's lead each day is 4
import pandas as pd
from scipy.stats import poisson

amir_deals = pd.read_csv("amir_deals (1).csv")
# Probability of > 10 responses
prob_over_10 = 1-poisson.cdf(10, 4)

print(prob_over_10)
# Out:
# 0.0028397661205137315

# %%
#the exponantial distribution
#Modeling time between leads

#exponential dist focus on caulculating time between events in the poisson dist
#what is the probability of time less than hour for amir's deal?
import pandas as pd
from scipy.stats import expon

amir_deals = pd.read_csv("amir_deals (1).csv")
# Print probability response takes < 1 hour
print(expon.cdf(1, scale=2.5))
# Out:
# 0.3296799539643607

# %%
#the exponantial distribution
#Modeling time between leads

#find the probability of amir's time > 4 hours to respond a lead
import pandas as pd
from scipy.stats import expon

amir_deals = pd.read_csv("amir_deals (1).csv")

# Print probability response takes > 4 hours
print(1 - expon.cdf(4, scale=2.5))
# Out:
# 0.20189651799465536

# %%
#the exponantial distribution
#Modeling time between leads

#find the probability of amir's time from 3 to 4 hours to respond a lead
import pandas as pd
from scipy.stats import expon

amir_deals = pd.read_csv("amir_deals (1).csv")

# Print probability response takes 3-4 hours
print(expon.cdf(3, scale=2.5) - expon.cdf(4, scale=2.5))
# Out:
# -0.09929769391754684

# %%
#Correlation
#relationship between variables

#examine the relaionship between between a country's life expectancy (life_exp) and happiness score (happiness_score)
import pandas as pd
import seaborn as sns

world_happiness = pd.read_csv("world_happiness (1).csv")
# Create a scatterplot of happiness_score vs. life_exp and show
sns.scatterplot(x="life_exp", y="happiness_score", data=world_happiness)

# Show plot
plt.show()

# %%
#Correlation
#relationship between variables with trandline
import pandas as pd
import seaborn as sns

world_happiness = pd.read_csv("world_happiness (1).csv")
# Create a scatterplot of happiness_score vs. life_exp and show
sns.lmplot(x="life_exp", y="happiness_score", data=world_happiness, ci=None)

# Show plot
plt.show()

# %%
#Correlation
#relationship between variables with trandline
import pandas as pd
import seaborn as sns

world_happiness = pd.read_csv("world_happiness (1).csv")
# Create scatterplot of happiness_score vs life_exp with trendline
sns.lmplot(x='life_exp', y='happiness_score', data=world_happiness, ci=None)

# Show plot
plt.show()

# Correlation between life_exp and happiness_score
cor = world_happiness["life_exp"].corr(world_happiness["happiness_score"])

print(cor)
# Out:
# 0.7802249053272062

# %%
#correlation coveats

#the problem with correlation is that
#correlation relationship is measures only strength of linear relationship
#so that, correlation relationshp does not mean x causes y
import pandas as pd
import seaborn as sns

world_happiness = pd.read_csv("world_happiness (1).csv")
# Scatterplot of gdp_per_cap and life_exp
sns.scatterplot(x="gdp_per_cap", y="life_exp", data=world_happiness)

# Show plot
plt.show()

# Correlation between gdp_per_cap and life_exp
cor = world_happiness["gdp_per_cap"].corr(world_happiness["life_exp"])

print(cor) #correlation only measures linear relationship
# Out:
# 0.7019547642148012

# %%
#transforming variables
#if we got a skewed distributions, we need to transform it to get a linear relationsip form
#so that, it will be able to calculate correlation
import pandas as pd
import seaborn as sns

world_happiness = pd.read_csv("world_happiness (1).csv")
# Create log_gdp_per_cap column
world_happiness['log_gdp_per_cap'] = np.log(world_happiness["gdp_per_cap"])

# Scatterplot of happiness_score vs. log_gdp_per_cap
sns.scatterplot(x="log_gdp_per_cap", y="happiness_score", data=world_happiness)
plt.show()

# Calculate correlation
cor = world_happiness["log_gdp_per_cap"].corr(world_happiness["happiness_score"])
print(cor)
# Out:
# 0.8043146004918288
